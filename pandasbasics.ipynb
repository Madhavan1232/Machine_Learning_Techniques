# %% [markdown]
# <span style="font-size:30px"><B>Pandas Library<B></span>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing

# %%
housedataset=fetch_california_housing()

# %%
print(housedataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]]), 'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]), 'frame': None, 'target_names': ['MedHouseVal'], 'feature_names': ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude'], 'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n:Number of Instances: 20640\n\n:Number of Attributes: 8 numeric, predictive attributes and the target\n\n:Attribute Information:\n    - MedInc        median income in block group\n    - HouseAge      median house age in block group\n    - AveRooms      average number of rooms per household\n    - AveBedrms     average number of bedrooms per household\n    - Population    block group population\n    - AveOccup      average number of household members\n    - Latitude      block group latitude\n    - Longitude     block group longitude\n\n:Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,000).\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nA household is a group of people residing within a home. Since the average\nnumber of rooms and bedrooms in this dataset are provided per household, these\ncolumns may take surprisingly large values for block groups with few households\nand many empty houses, such as vacation resorts.\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. rubric:: References\n\n- Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n  Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %%
type(housedataset)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# <span style="font-size:30px"><B>Pandas Dataframe<B></span>

# %%
housedf=pd.DataFrame(housedataset.data,columns=housedataset.feature_names)

# %%
housedf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housedf.shape
# Out:
# (20640, 8)

# %% [markdown]
# <span style="font-size:20px"><b>Importing the data from csv file to a pandas dataframe</b></span>

# %%
diabetes_df=pd.read_csv("D:\SKCET\SUBJECTS\Machine Learning Technique\datasets\diabetes.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# /tmp/ipython-input-2163899113.py:2: SyntaxWarning: invalid escape sequence '\S'
#   diabetes_df=pd.read_csv("D:\SKCET\SUBJECTS\Machine Learning Technique\datasets\diabetes.csv")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2163899113.py in <cell line: 0>()
#       1 #csv file to pandas Dataframe
# ----> 2 diabetes_df=pd.read_csv("D:\SKCET\SUBJECTS\Machine Learning Technique\datasets\diabetes.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\SKCET\\SUBJECTS\\Machine Learning Technique\\datasets\\diabetes.csv'

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148           72.0             35    169.5  33.6
# 1            1       85           66.0             29    102.5  26.6
# 2            8      183           64.0             32    169.5  23.3
# 3            1       89           66.0             23     94.0  28.1
# 4            0      137           40.0             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# creating a Dataframe using random values

# %%
randomdf=pd.DataFrame(np.random.rand(20,10))
randomdf.shape
# Out:
# (20, 10)

# %%
randomdf.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.448621  0.964470  0.515107  0.507985  0.165324  0.515174  0.113924
# 1  0.164509  0.996890  0.299721  0.962995  0.394727  0.647369  0.592358
# 2  0.839498  0.833878  0.395400  0.864246  0.265055  0.150091  0.077750
# 3  0.093550  0.960120  0.134554  0.069061  0.710359  0.773419  0.618460
# 4  0.289489  0.826306  0.987787  0.233814  0.567642  0.929197  0.677060
#
#           7         8         9
# 0  0.584706  0.057783  0.608840
# 1  0.109436  0.877826  0.313825
# 2  0.411260  0.567381  0.554897
# 3  0.246296  0.259480  0.442254
# 4  0.547859  0.762989  0.604493

# %%
#Finding the number of missing values
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#counting the values based on the labels
diabetes_df.value_counts('Outcome')
#diabetes_df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:18e375d5-e0e8-43e6-8594-a43bebc77fb5.png)

# %%
markdata_df=pd.read_csv("D:\SKCET\SUBJECTS\Machine Learning Technique\datasets\mark.csv",header=None)

# %%
markdata_df.shape
# Out:
# (6, 3)

# %%
print(markdata_df)
# Out:
#    0   1   2
# 0  1  90  88
# 1  2  78  78
# 2  3  88  81
# 3  4  92  78
# 4  5  89  77
# 5  6  64  80

# %%
markdata_df.columns=["Roll","attendance","mark"]

# %%
print(markdata_df)
# Out:
#    Roll  attendance  mark
# 0     1          90    88
# 1     2          78    78
# 2     3          88    81
# 3     4          92    78
# 4     5          89    77
# 5     6          64    80

# %% [markdown]
# <b> Statistical Measures<b>

# %%
#count or number of values
markdata_df.count()
# Out:
# Roll          6
# attendance    6
# mark          6
# dtype: int64

# %%
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#Mean value column wise
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     121.677083
# BloodPressure                72.389323
# SkinThickness                29.089844
# Insulin                     141.753906
# BMI                          32.434635
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#Standard Deviation column wise
diabetes_df.std()
# Out:
# Pregnancies                  3.369578
# Glucose                     30.464161
# BloodPressure               12.106039
# SkinThickness                8.890820
# Insulin                     89.100847
# BMI                          6.880498
# DiabetesPedigreeFunction     0.331329
# Age                         11.760232
# Outcome                      0.476951
# dtype: float64

# %%
#Minimum vlaue
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                     44.000
# BloodPressure               24.000
# SkinThickness                7.000
# Insulin                     14.000
# BMI                         18.200
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#Maximum value
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# All the statistical Measures about the dataframe
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.677083      72.389323      29.089844  141.753906
# std       3.369578   30.464161      12.106039       8.890820   89.100847
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      25.000000  102.500000
# 50%       3.000000  117.000000      72.000000      28.000000  102.500000
# 75%       6.000000  140.250000      80.000000      32.000000  169.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.434635                  0.471876   33.240885    0.348958
# std      6.880498                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.050000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Adding a column to a Dataframe
housedf['Price']=housedataset.target

# %%
housedf.head()
housedf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
housedf.shape
# Out:
# (20640, 9)

# %%
#Removing a row
#drop() does NOT modify the dataframe permanently
#It returns a new dataframe
newhousedf=housedf.drop(index=0,axis=0)
newhousedf.shape
# Out:
# (20639, 9)

# %%
newhousedf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
#
#    Longitude  Price
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422
# 5    -122.25  2.697

# %%
#Removing a column
newhousedf.drop(columns='MedInc',axis=1,inplace=True)   #Now the original dataframe is modified.
newhousedf.head()
# Out:
#    HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude  \
# 1      21.0  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2      52.0  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3      52.0  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4      52.0  6.281853   1.081081       565.0  2.181467     37.85    -122.25
# 5      52.0  4.761658   1.103627       413.0  2.139896     37.85    -122.25
#
#    Price
# 1  3.585
# 2  3.521
# 3  3.413
# 4  3.422
# 5  2.697

# %%
# Locating a row using the index value
housedf.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Price           3.521000
# Name: 2, dtype: float64

# %%
# Locating a particular Column
housedf.iloc[:,0]    # first column
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64

# %%
# Locating a particular Column
housedf.iloc[:,-1]    # Last column
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
#Correlation
housedf.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# Population -0.108785   0.099773 -0.024650
# AveOccup    0.002366   0.002476 -0.023737
# Latitude    1.000000  -0.924664 -0.144160
# Longitude  -0.924664   1.000000 -0.045967
# Price      -0.144160  -0.045967  1.000000
